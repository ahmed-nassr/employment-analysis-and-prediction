# %% [markdown]
# # Code

# %%
import os

# %%
os.chdir('..')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/raw/employment.csv')

# %%
df.rename(columns={'Unnamed: 0': 'id'}, inplace=True)
df.columns
# Out:
# Index(['id', 'Age', 'Accessibility', 'EdLevel', 'Employment', 'Gender',
#        'MentalHealth', 'MainBranch', 'YearsCode', 'YearsCodePro', 'Country',
#        'PreviousSalary', 'HaveWorkedWith', 'ComputerSkills', 'Employed'],
#       dtype='str')

# %%
df[df['HaveWorkedWith'].isna()]
# Out:
#           id  Age Accessibility        EdLevel  Employment Gender  \
# 1161    1161  >35            No  Undergraduate           1    Man
# 2443    2443  >35            No          Other           1    Man
# 2533    2533  >35            No            PhD           1    Man
# 2657    2657  <35            No         Master           0  Woman
# 5797    5797  <35            No  Undergraduate           1    Man
# ...      ...  ...           ...            ...         ...    ...
# 69865  69865  <35            No          Other           1    Man
# 71795  71795  <35            No  Undergraduate           1    Man
# 72153  72153  >35           Yes          Other           1    Man
# 72588  72588  <35            No          Other           1    Man
# 72593  72593  <35            No  Undergraduate           1  Woman
#
#       MentalHealth MainBranch  YearsCode  YearsCodePro  \
# 1161           Yes        Dev         36            32
# 2443            No        Dev          7             6
# ...

# %%
df[(df['ComputerSkills'] == 0) | df['HaveWorkedWith'].isna()]
# Out:
#           id  Age Accessibility        EdLevel  Employment Gender  \
# 1161    1161  >35            No  Undergraduate           1    Man
# 2443    2443  >35            No          Other           1    Man
# 2533    2533  >35            No            PhD           1    Man
# 2657    2657  <35            No         Master           0  Woman
# 5797    5797  <35            No  Undergraduate           1    Man
# ...      ...  ...           ...            ...         ...    ...
# 69865  69865  <35            No          Other           1    Man
# 71795  71795  <35            No  Undergraduate           1    Man
# 72153  72153  >35           Yes          Other           1    Man
# 72588  72588  <35            No          Other           1    Man
# 72593  72593  <35            No  Undergraduate           1  Woman
#
#       MentalHealth MainBranch  YearsCode  YearsCodePro  \
# 1161           Yes        Dev         36            32
# 2443            No        Dev          7             6
# ...

# %% [markdown]
# for every computer skill==0, HaveWOrkedWith will be missing

# %%
df.rename(columns={'Age' : 'AgeAbove35'}, inplace=True)

# %%
df['AgeAbove35']=df['AgeAbove35'].replace('>35' , 1).replace('<35' , 0)

# %%
df['AgeAbove35']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 73457    0
# 73458    1
# 73459    0
# 73460    0
# 73461    0
# Name: AgeAbove35, Length: 73462, dtype: object

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                14696
# Germany                                                  5395
# India                                                    5360
# United Kingdom of Great Britain and Northern Ireland     4688
# Canada                                                   2779
#                                                         ...
# Gambia                                                      1
# Burkina Faso                                                1
# Mauritania                                                  1
# Burundi                                                     1
# Seychelles                                                  1
# Name: count, Length: 172, dtype: int64

# %%
df['HaveWorkedWith'].value_counts()
# Out:
# HaveWorkedWith
# Python                                                                                                                     71
# Python;Git                                                                                                                 54
# C++;Python                                                                                                                 49
# C++                                                                                                                        41
# C++;Python;Git                                                                                                             36
#                                                                                                                            ..
# C;C#;C++;Microsoft Azure;SQLite                                                                                             1
# ...

# %%
df['HaveWorkedWith']=df['HaveWorkedWith'].str.split(';')
skills=df[['id','HaveWorkedWith']].explode(column='HaveWorkedWith')

# %%
skills
# Out:
#           id        HaveWorkedWith
# 0          0                   C++
# 0          0                Python
# 0          0                   Git
# 0          0            PostgreSQL
# 1          1            Bash/Shell
# ...      ...                   ...
# 73460  73460              DynamoDB
# 73460  73460  Microsoft SQL Server
# 73460  73460                SQLite
# 73461  73461                Python
# 73461  73461                Docker
#
# [986527 rows x 2 columns]

# %%
df['MainBranch'].value_counts()
# Out:
# MainBranch
# Dev       67396
# NotDev     6066
# Name: count, dtype: int64

# %%
df['Accessibility'] = df['Accessibility'].str == "Yes"

# %%
df['MentalHealth'] = df['MentalHealth'].str == "Yes"

# %%
df.to_csv('data/cleaned/employment_cleaned.csv', index=False)

# %%
skills.to_csv('data/cleaned/skills.csv', index=False)
